# %%
# !sudo add-apt-repository ppa:alex-p/tesseract-ocr
# Out:
#   The Tesseract OCR engine was one of the top 3 engines in the 1995
#  UNLV Accuracy test. Between 1995 and 2006 it had little work done on
#  it, but since then it has been improved extensively by Google and is
#  probably one of the most accurate open source OCR engines
#  available. It can read a wide variety of image formats and convert
#  them to text in over 40 languages. This package includes the command
#  line tool.
#  More info: https://launchpad.net/~alex-p/+archive/ubuntu/tesseract-ocr
# Press [ENTER] to continue or Ctrl-c to cancel adding it.
#
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [41.5 kB]
# Get:4 http://ppa.launchpad.net/alex-p/tesseract-ocr/ubuntu bionic InRelease [15.4 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:14 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://ppa.launchpad.net/alex-p/tesseract-ocr/ubuntu bionic/main amd64 Packages [26.5 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,703 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [872 kB]
# Fetched 2,930 kB in 2s (1,366 kB/s)
# Reading package lists... Done

# %%
# !sudo apt-get update
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 http://ppa.launchpad.net/alex-p/tesseract-ocr/ubuntu bionic InRelease
# Hit:4 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libtesseract4 tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# The following packages will be upgraded:
#   libtesseract4
# 1 upgraded, 3 newly installed, 0 to remove and 20 not upgraded.
# Need to get 6,161 kB of archives.
# After this operation, 16.3 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/alex-p/tesseract-ocr/ubuntu bionic/main amd64 libtesseract4 amd64 4.1.1+git4247-97079fa3-1ppa1~bionic1 [1,260 kB]
# Get:2 http://ppa.launchpad.net/alex-p/tesseract-ocr/ubuntu bionic/main amd64 tesseract-ocr-eng all 1:4.0.0+git39-6572757-1ppa1~bionic1 [1,589 kB]
# Get:3 http://ppa.launchpad.net/alex-p/tesseract-ocr/ubuntu bionic/main amd64 tesseract-ocr-osd all 1:4.0.0+git39-6572757-1ppa1~bionic1 [2,992 kB]
# Get:4 http://ppa.launchpad.net/alex-p/tesseract-ocr/ubuntu bionic/main amd64 tesseract-ocr amd64 4.1.1+git4247-97079fa3-1ppa1~bionic1 [320 kB]
# Fetched 6,161 kB in 2s (2,497 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 145480 files and directories currently installed.)
# Preparing to unpack .../libtesseract4_4.1.1+git4247-97079fa3-1ppa1~bionic1_amd64.deb ...
# Unpacking libtesseract4:amd64 (4.1.1+git4247-97079fa3-1ppa1~bionic1) over (4.00~git2288-10f4998a-2) ...
# Selecting previously unselected package tesseract-ocr-eng.
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.0.0+git39-6572757-1ppa1~bionic1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.0.0+git39-6572757-1ppa1~bionic1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.0.0+git39-6572757-1ppa1~bionic1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.0.0+git39-6572757-1ppa1~bionic1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1+git4247-97079fa3-1ppa1~bionic1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1+git4247-97079fa3-1ppa1~bionic1) ...
# Setting up libtesseract4:amd64 (4.1.1+git4247-97079fa3-1ppa1~bionic1) ...
# Setting up tesseract-ocr-osd (1:4.0.0+git39-6572757-1ppa1~bionic1) ...
# Setting up tesseract-ocr-eng (1:4.0.0+git39-6572757-1ppa1~bionic1) ...
# Setting up tesseract-ocr (4.1.1+git4247-97079fa3-1ppa1~bionic1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# !sudo apt install libtesseract-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libarchive-dev liblept5 libleptonica-dev
# The following NEW packages will be installed:
#   libarchive-dev libleptonica-dev libtesseract-dev
# The following packages will be upgraded:
#   liblept5
# 1 upgraded, 3 newly installed, 0 to remove and 19 not upgraded.
# Need to get 4,327 kB of archives.
# After this operation, 15.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-dev amd64 3.2.2-3.1ubuntu0.6 [470 kB]
# Get:2 http://ppa.launchpad.net/alex-p/tesseract-ocr/ubuntu bionic/main amd64 liblept5 amd64 1.78.0-1+nmu1ppa1~bionic1 [985 kB]
# Get:3 http://ppa.launchpad.net/alex-p/tesseract-ocr/ubuntu bionic/main amd64 libleptonica-dev amd64 1.78.0-1+nmu1ppa1~bionic1 [1,375 kB]
# Get:4 http://ppa.launchpad.net/alex-p/tesseract-ocr/ubuntu bionic/main amd64 libtesseract-dev amd64 4.1.1+git4247-97079fa3-1ppa1~bionic1 [1,496 kB]
# Fetched 4,327 kB in 2s (2,184 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 145532 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.2.2-3.1ubuntu0.6_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.2.2-3.1ubuntu0.6) ...
# Preparing to unpack .../liblept5_1.78.0-1+nmu1ppa1~bionic1_amd64.deb ...
# Unpacking liblept5 (1.78.0-1+nmu1ppa1~bionic1) over (1.75.3-3) ...
# Selecting previously unselected package libleptonica-dev.
# Preparing to unpack .../libleptonica-dev_1.78.0-1+nmu1ppa1~bionic1_amd64.deb ...
# Unpacking libleptonica-dev (1.78.0-1+nmu1ppa1~bionic1) ...
# Selecting previously unselected package libtesseract-dev:amd64.
# Preparing to unpack .../libtesseract-dev_4.1.1+git4247-97079fa3-1ppa1~bionic1_amd64.deb ...
# Unpacking libtesseract-dev:amd64 (4.1.1+git4247-97079fa3-1ppa1~bionic1) ...
# Setting up liblept5 (1.78.0-1+nmu1ppa1~bionic1) ...
# Setting up libarchive-dev:amd64 (3.2.2-3.1ubuntu0.6) ...
# Setting up libleptonica-dev (1.78.0-1+nmu1ppa1~bionic1) ...
# Setting up libtesseract-dev:amd64 (4.1.1+git4247-97079fa3-1ppa1~bionic1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !sudo pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading https://files.pythonhosted.org/packages/a0/e6/a4e9fc8a93c1318540e8de6d8d4beb5749b7960388a7c7f27799fc2dd016/pytesseract-0.3.7.tar.gz
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from pytesseract) (7.0.0)
# Building wheels for collected packages: pytesseract
#   Building wheel for pytesseract (setup.py) ... done
#   Created wheel for pytesseract: filename=pytesseract-0.3.7-py2.py3-none-any.whl size=13945 sha256=a641b5e2073c2f267dc97648111927bef00baf74ccbec37cc4db118353a83952
#   Stored in directory: /root/.cache/pip/wheels/81/20/7e/1dd0daad1575d5260916bb1e9781246430647adaef4b3ca3b3
# Successfully built pytesseract
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.7

# %%
#Checking the installation.
# !tesseract --version
# Out:
# tesseract 4.1.1-rc2-25-g9707
#  leptonica-1.78.0
#   libgif 5.1.4 : libjpeg 8d (libjpeg-turbo 1.5.2) : libpng 1.6.34 : libtiff 4.0.9 : zlib 1.2.11 : libwebp 0.6.1 : libopenjp2 2.3.0
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.2.2 zlib/1.2.11 liblzma/5.2.2 bz2lib/1.0.6 liblz4/1.7.1

# %%
from IPython.display import Image

# %%
Image("/content/drive/MyDrive/ocr/ocr.jpg")

# %%
import cv2
import numpy as np
import pytesseract
from PIL import Image

# Path of working folder on Disk

def get_string(img_path):
    # Read image with opencv
    img = cv2.imread(img_path)

    # Convert to gray
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply dilation and erosion to remove some noise
    kernel = np.ones((1, 1), np.uint8)
    img = cv2.dilate(img, kernel, iterations=1)
    img = cv2.erode(img, kernel, iterations=1)

    # Write image after removed noise
    cv2.imwrite("/content/drive/MyDrive/ocr/ocr form-1.jpg", img)

    #  Apply threshold to get image with only black and white
    #img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)

    # Write the image after apply opencv to do some ...
    cv2.imwrite(img_path, img)

    # Recognize text with tesseract for python
    result = pytesseract.image_to_string(Image.open(img_path))

    # Remove template file
    #os.remove(temp)

    return result


print ('--- Start recognize text from image ---')
print(get_string('/content/drive/MyDrive/ocr/ocr form-1.jpg'))

print ("------ Done -------")
# Out:
# --- Start recognize text from image ---
# $8) General Insurance Company Limited
#
# IRDAI of India Reg Nv 144 dated 15/12/2009 | CIN USECOOMH2009PLCI9D545 | ul _p12-57-V02-11-12 @ sBisener:. 5
# k .
# PRIVATE CAR/TWO WHEELER INSURANCE POLIcy SBG-MO-
#
# fect seca a3 www.sbigeneral.in/download tR Brey es |
# Proposal Form
#
# The queries stated below are minimum Tequirement to be furnished by a Proposer,
# _j;PuCar | | Two Wheeler Proposal for: | | New
# Uta s USE
#
# BIGeneral
#
# sp R ANCE
#
# 1800 102 1111
# Cal! Coll Free) 1800 22 1111 | =bwenerctin
#
# | | Package Cd Liability
#
# The insurer ma ting purpose.
# y Seek sired for underwri
# ee To be filled in BLOCK LETTERS ONLY
#
# Renewal Rol ver [_| Used Endorsement
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ProposalNo, | y | my t
# Sig No. S SS fa i o cE) 1S] GAA APP Erle bel AM Cade “B/S! Le 4 Code
# to A. Inodd SOCLIFSdt 2) Oy eq) Secondary ei ele ale e/HAle Agra
# Inwal . | M = i
# Break-in ° el Bom lan MIT 7 Woy Hepa ol Pome (7312. 2A Sol | Receipt Date \
# ispctontio, | VARY Ge asigc Te gehl ; SP Code
# Business Sector {_| Urban Rural | { Social GSTINASDN tate Segment
# * Customer Segme
# PROPOSER DETAILS? ee = Gis Nees og bus :
# It you have existing relationship with SBI General Insurance then Please provide au ID 7 Policy number i
# Tr: i i ——
# Tile . ivtre male
# Mivlnle| tne [Ao ord dd MONIAIME NED aECRIE Tal o Lor Wels ee lhe
# Gender CI Male [7 Feral THO? T2410] T]
# | i Female [} Third Gender ae (OPFTIT 1 4144) conactno. (415163 14 FAA: j
# Emalio [KY [Z/@'4 [la ib]. icjom~ [TTT LT TTTy LL Mobile No.[ |_|
# Occupation of the Insured LT] | ] 1 ; 2
# DOB of Proposer [|] | vf | | ~ ~ : PAN No. eNiy aris 2
# Address of House No. T T T ' , 5 T
# the Proposer ° a SA tit ft tf | Block (zt = [| Bullaing |) | Fi- [1
# Locality [GlOlAl bla q ial suet [Slelaldioiw | | ry “) Oty elo hk
# State WelStl Ipleh/ qlalt ra] TIA
# eS) leh iqalel |] Pin code (7 [0] 010/011 oo EASE
# Sunnie Yes [No]
# 2/4 1[2/2] of o[2) til midnight of i [2d] 0] 1B on 0 Boing
# Previous Year Policy Period 14 orlFr le [Uololy orca VY. tn] Meet pane "4 | Amount | 12079
# ‘ane MLL LET VT TTT TT) peotoe (AISRo Wi [eATS fT TTT TT
# Previous Insu-er | | TTT TITITIT TI Terit_ i itli li |
# Usage of Vehicle Ld Business FI Private Driver Age Driver's Driving Experience | C ate] Parking Type [| as we blic Steet icSueet [| Ae ound
# Date of Registration Tey, J T1 gro Ty IDE eT mm TOUTE Ea. =
# ros te tL aT mt ate i : j ity. i d 4 ovation me es !
# Vehicle Make, Model & Variant Month & Year of Mfg. | Registration Number 4 Engine Number _| Chassis Number Seating Capacity L cc | FuelUsed |
# L |
# Vehicle Insured Declared Value Rs. Electiical |  Non-Electrical Trailer Value Rs. | Side Car ValueRs.| {| CNG/|_} LPGKItRs. | Total IDV Rs.
# Accessories Rs. | Accessories Rs. | (Two wheeler) (not provided by manufacturers) |
# A) ® Fl © o €@) a =! (A+B+C+D+E+A)
# a a tT TC
# Vehicle modifi cation | Yes oO No I Yes provide details
# | Legal Liability ta Paid Driver fa No of Persons L | PA To Owner Driver (Please give delaits of Nomination) {| | PAto Unnamed Passenger SumInsuredRs.
# Nominee Details: Name eI ni 1[WJa m_ LD! ALS} | | iii ff oe WI gaa q 4 14 Relation Brother |
# Name of the Appointee Inlh “iT EQ T T intee Relationship
# a Nominee is a Sinor) |_| | | | | to the Nominee Bro Kner cr =
#
#
#
#
#
# all Engine oer (Pvt Car only) CL Return To Invoice
# L rd Addilional road side assistance (Pvt Car only)
# |__] Inconvenience Allowance (Pvt Car Only) Rs.
#
# Depreciation Reimbursement (Pvt Car Only) LC] Cover for Consumables (Pvt Car ot
# ' Basic road side assistance (Pvt Car only)
#
# Protection of NCB (Cover available to protect NCB upto 50% Only as per elig:bility) (4
# [ Cover for Key Replacement (Pvt Car only)
#
#
#
#
#
# LJ
# J Loss of Personal Belongings (Pvt Car Only) Rs.
#
# | Enhance PA Cover for Insured (Owner Driver) / unnamed passengers / Pald Drivers (Pvt Car only) sum Insured per person Rs.
# Hoan Cash Cover for Insured (Owner Driver) / ila passengers / Paid Drivers (Pvt Car only) Rs. —
#
# ei eet
#
#
#
#
#
#
#
#
#
#
# EMI Protector (Private car only)
#
#
#
#
#
#
#
#
#
# aaenne
#
# |
# Loan Account No. [
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# NSURED'S DECLARED VALUE (OV) ORTHEVEHIC
#
# ehicle will be deemed to be the sum insured for the purpose of the policy & will be fixed on the basis of the manufacturers listed selling price of the brand and adjusted for Depreciation as per schedule below
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The IDV of the ver ~ of Depreciation — [ Age of the Vehicle i | SeofDepreciation
# H _Age of the Vehicle — - = 5% Exceeding 2 years but not exceeding 3 years _ | 30% |
# | Not Exceeding 6 mon ang tyr 45% Exceeding 3 years but not exceeding 4 years |
# | Exceeding 6 months butnot Exceeding Exceeding 4 yea ae 1
# Le ceded raaaing 292208 20% eeding 4 years but not exceeding 5 years
#
# Exceed = ae :
#
#
#
#
#
#
#
#
#
#
#
# DEDUCTIBLE
# Rs. 2500
#
# Rs. 5000
# Rs. 7500
# Rs. 15000
#
#
#
#
#
#
#
#
#
# PRIVATE CAR,
# (_] Std min deductible Plus
# [_] Std min deductible Plus
# [__| Std min deductible Plus
#
# (J Stemin deductible Pus
#
#
#
#
#
#
#
#
#
#
#
# Corporate & Registered Office. *Natraj’, 301, Junction ot Western Express Highway &
#
#
#
# Andheri - kurla Road, Andheri (East), Mumbai - 420 98¢
#
# TWO WHEELER
#
#
#
#
#
# DEDUCTIBLE |
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [LJStdmindeductiblePlus 8.500,
# _| Std min deductible Plus 's. 750
# [_JStdmin deductible Pus Rs. 1000
# L_] Std min deductible Plus Rs. 1500
# _] Sta min deductible Plus - Rs. sot |
#
#
#
# Version No. 2.0. December 2018 | Print December 2018_2 0
#
# ------ Done -------
